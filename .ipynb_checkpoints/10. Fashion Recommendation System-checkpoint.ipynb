# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
import keras 
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
# Load the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Pre-process and normalize the data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
for i in range(1, 10):
     # Create a 3x3 grid and place the
     # image in ith position of grid
     plt.subplot(3, 3, i)
     # Insert ith image with the color map 'grap'
     plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
     # Display the entire plot
     plt.show()

# %%
model = keras.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28
, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train , y_train, epochs=1)
# Out:
# 1875/1875 [==============================] - 41s 19ms/step - loss: 0.4662 - accuracy: 0.8326

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 2s - loss: 0.3725 - accuracy: 0.8671 - 2s/epoch - 7ms/step
#
# Test accuracy: 0.8671000003814697

# %%
preds = model.predict(x_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %%
preds
# Out:
# array([[9.1806451e-06, 2.0662853e-07, 2.1158783e-06, ..., 3.6150854e-02,
#         1.8813054e-04, 9.6192211e-01],
#        [1.4182565e-02, 1.8394445e-06, 9.6123230e-01, ..., 1.7985458e-09,
#         1.3497857e-04, 7.1004342e-07],
#        [3.5462683e-06, 9.9999356e-01, 1.3914940e-09, ..., 3.3061900e-11,
#         3.8317671e-07, 3.0275962e-10],
#        ...,
#        [2.6408125e-02, 1.4314033e-06, 1.2655265e-03, ..., 2.5884572e-05,
#         9.5758188e-01, 6.6042492e-07],
#        [1.5523892e-05, 9.9945778e-01, 3.9149121e-08, ..., 5.9240783e-08,
#         1.3409221e-05, 1.6524686e-07],
#        [4.0157903e-03, 8.9247524e-06, 8.5982279e-04, ..., 6.3304478e-01,
#         5.8677774e-02, 6.3715731e-03]], dtype=float32)
